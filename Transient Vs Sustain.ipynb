# %% [markdown]
# #Transient Vs. Sustain
#
# Stephen Welch, February 6, 2014
#
# One of the reasons working with music signals can be challenging is the inherit non-stationarity of musical sounds, especially acoustic instruments. A high level example of this non-stationarity is the inconsistent system behavior between transients and sustains.
#
# Here we'll make an effort seperate transients and sustains using wavelet decomposition. In practice, the statistical nonstationarity breaks down over more than just transient/sustain behavior, this represents a first attempt at reducing non-stationarity using a transient/sustain paradigm.

# %% [markdown]
# ##Import Data

# %%
import cPickle as pickle

pickleName = 'taylorJan23'

pickleFileName = "pickles/" + pickleName + ".pickle"
pickleFile = open(pickleFileName, 'rb')
alignedSignals = pickle.load(pickleFile)
pickleFile.close()

# %% [markdown]
# ##Compute Wavelet Coefficients

# %%
import pywt

#Compute SWT
def computeWaveletCoefficients(data, name='db4', numLevels = 2):
    #Create wavelet object
    w = pywt.Wavelet(name)
    
    #Compute wavelet coefficients, use swt to avoid decimation:
    c = pywt.swt(data, w, level=numLevels)
    
    #Put all coefficients into a big matrix, XFF
    XFF = np.zeros((len(data), numLevels + 1))

    XFF[:,0] = c[0][0]
    for i in range(len(c)):
        XFF[:,i+1] = c[i][1]
        
    #Throw out last 1000 samples, wierd stuff tends to happen at the wend of wavelet 
    return XFF[:-1000,:]

# %%
mic1 = alignedSignals['mic1']
mic2 = alignedSignals['mic2']
mic3 = alignedSignals['mic3']
piezo = alignedSignals['piezo']

# %%
c = computeWaveletCoefficients(piezo, name='db20', numLevels=4)

#Normalize Wavelet Coefficients:
normalizationCoeffients = amax(abs(c),axis=0)
cNorm = abs(c)/normalizationCoeffients

# %%
cNorm.shape, mic1.shape, piezo.shape
# Out:
# ((1189400, 5), (1190400,), (1190400,))

# %% [markdown]
# Reduce length for now to save compuational time:

# %%
rangeToAnalyze = arange(0, 10000)

cNorm = cNorm[rangeToAnalyze, :]
mic1 = mic1[rangeToAnalyze]
mic2 = mic2[rangeToAnalyze]
mic3 = mic3[rangeToAnalyze]
piezo = piezo[rangeToAnalyze]

# %% [markdown]
# ##Plot wavelet coefficients
#
# - Higher frequency wavelets as we go down on the plot.

# %%
colorz = ['r','g','b','y','m','c','k']
#rangeToPlot = arange(0,12000)

fig = figure(0,(12,12))
for i in range(c.shape[1]):
    subplot(c.shape[1]+1, 1, i+1)
    plot(cNorm[:,i], c=colorz[i])
    grid(1)

# %% [markdown]
# High frequency wavelet coefficients respond very quickly to transients, we'll use these to detect and pick out transients.

# %% [markdown]
# ###Grab HF Wavelet component and square:

# %%
#Squared HF Comp.
cHF = cNorm[:,-1]**2
cSquared = cHF/np.max(cHF)

cSquared.shape, amax(cSquared)
# Out:
# ((10000,), 1.0)

# %% [markdown]
# ###Detect transients using adaptive gating method:

# %%
import time

def waveletGateAdaptive(input, threshVec, openThresh, samplesToWait, deltaUpParams, deltaDownParams):
    
    startTime = time.clock()
    transientFlags = []
    
    deltaUp = deltaUpParams[0]*sigmoidPrime(linspace(-1*deltaUpParams[1], deltaUpParams[1], 1024))
    deltaDown = deltaDownParams[0]*sigmoidPrime(linspace(-1*deltaDownParams[1],deltaUpParams[1],1024))
    
    gateVal = np.zeros(len(input))
    
    samplesToWaitCount = 0
    
    for i in arange(1, len(input)):
        samplesToWaitCount += 1
        if samplesToWaitCount > samplesToWait:
            if input[i] > threshVec[i]:
                gateVal[i] = gateVal[i-1] + deltaUp[ceil(len(deltaUp)*gateVal[i-1])-1]
                if gateVal[i] > openThresh:
                    transientFlags.append(i)
                    gateVal[i] = 0
                    samplesToWaitCount = 0

            else:
                gateVal[i] = gateVal[i-1] - deltaDown[ceil(len(deltaDown)*gateVal[i-1])-1]

            if gateVal[i] > 1:
                gateVal[i] = 1
            elif gateVal[i] < 0:
                gateVal[i] = 0
                
    print "Time Elapsed = " + str(time.clock()-startTime)
                
    return gateVal, transientFlags

# %%
sys.path.append('supportFunctions')
from supportFunctions import makeToeplitz

# %%
filterLength = 1000

threshVec = np.mean(makeToeplitz(cSquared, filterLength), axis=1)

#Compensate for filter shifts:
shiftedAudio = piezo[filterLength-1:10000-1000]
cSquaredShifted = cSquared[filterLength-1:]

threshVec.shape, shiftedAudio.shape, cSquaredShifted.shape
# Out:
# ((9001,), (8001,), (9001,))

# %%
rangeToPlot = arange(0, 8000)

figure(0,(12,12))

subplot(4,1,1)
plot(shiftedAudio[rangeToPlot], c=[0.7,0.7,0.7])
plot(threshVec[rangeToPlot]*2)
grid(1)

legend(['Audio', 'Threshold'])

subplot(4,1,2)
plot(cSquaredShifted[rangeToPlot])
grid(1)

legend(['cSquared'])

# %% [markdown]
# Sigmoid is part of gating function:

# %%
def generalSigmoid(x, a):
    return 1/(1+exp(-a*x))

def sigmoidPrime(z):
    e = 1/(1+np.exp(z))
    return (1-e)*e

# %%
g, transientFlags = waveletGateAdaptive(cSquaredShifted, threshVec = 3*threshVec, openThresh = 0.7, \
                        samplesToWait = 600, deltaUpParams = [0.25, 5], deltaDownParams = [0.05, 5])
# Out:
# -c:26: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# -c:26: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# -c:26: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# -c:26: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# -c:26: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# -c:26: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# -c:26: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# -c:26: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# ...

# %%
rangeToPlot = arange(0,8000)

figure(0,(12,12))

subplot(4,1,1)
plot(shiftedAudio[rangeToPlot], c=[0.7,0.7,0.7])
plot(threshVec[rangeToPlot]*2)
grid(1)

legend(['Audio', 'Threshold'])

subplot(4,1,2)
plot(g[rangeToPlot],'g')
grid(1)

legend(['Gate'])

subplot(4,1,3)
plot(cSquaredShifted[rangeToPlot])
grid(1)

legend(['cSquared'])

# %% [markdown]
# Make gate masking function.

# %%
down = generalSigmoid(linspace(-5,5, 256), -1)

totalLength = len(down)
plot(down)

grid(1)

# %%
m = np.zeros((cSquaredShifted.shape[0], 2))

for flagCount in range(len(transientFlags)):
    m[transientFlags[flagCount]-128:transientFlags[flagCount], 0] = g[transientFlags[flagCount]-128:transientFlags[flagCount]]
    m[transientFlags[flagCount]:transientFlags[flagCount]+len(down), 0] = down

m[:,1] = 1-m[:,0]

# %%
#rangeToPlot = arange()

figure(0,(12,12))

subplot(4,1,1)
plot(shiftedAudio[rangeToPlot], c=[0.7,0.7,0.7])
plot(threshVec[rangeToPlot]*2)
grid(1)

legend(['Audio', 'Threshold'])

subplot(4,1,2)
plot(m[rangeToPlot,:])
grid(1)

legend(['Gate'])

subplot(4,1,3)
plot(cSquaredShifted[rangeToPlot])
grid(1)

legend(['cSquared'])

# %%
piezo.shape, mic1.shape, m.shape, shiftedAudio.shape
# Out:
# ((10000,), (10000,), (9001, 2), (8001,))

# %%
plot(piezo[filterLength:], c=[0.7, 0.7, 0.7])
plot(m)
grid(1)

# %%
m.shape, piezo.shape
# Out:
# ((9001, 2), (10000,))
